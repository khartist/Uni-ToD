# %% [markdown]
# <a href="https://colab.research.google.com/github/khartist/Uni-ToD/blob/main/test_uni_tod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/khartist/Uni-ToD.git
# Out:
# Cloning into 'Uni-ToD'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 150 (delta 25), reused 49 (delta 18), pack-reused 90 (from 1)
# Receiving objects: 100% (150/150), 7.76 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# !pip install transformers tensorboard nltk sentencepiece torch

# %%
# %rm -rf Uni-ToD/

# %%
CUDA_VISIBLE_DEVICES=1

# %%
# %cd Uni-ToD
# Out:
# /content/Uni-ToD

# %%
# !python train.py --dataset incar_vi --params_file config/gpt2/params.json --device cuda
# Out:
# 2025-06-16 12:34:37.489385: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750077277.509627    4835 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750077277.517129    4835 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 12:34:37.538605: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python eval.py --generate runs/uni-tod/incar_vi/checkpoint-287 --dataset incar_vi --generation_params_file config/gpt2/generation_params.json --eval_dataset test --output_file output_incar.json
# Out:
# 2025-06-16 15:31:22.771722: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750087882.792434   58468 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750087882.798699   58468 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 15:31:22.820592: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %pwd
# Out:
# '/content/Uni-ToD'

# %%
# !git add .

# %%
# !git commit -m "add incar_vi training setup"
# Out:
# [main f3fa8f0] add incar_vi training setup
#  24 files changed, 304406 insertions(+), 7 deletions(-)
#  create mode 100644 output_incar.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/added_tokens.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/config.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/eval_results.txt
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/merges.txt
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/params.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/pytorch_model.bin
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/special_tokens_map.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/tokenizer.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/tokenizer_config.json
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/training_args.bin
#  create mode 100644 runs/uni-tod/incar_vi/checkpoint-287/vocab.json
# ...

# %%
# !git config --global user.email "tnkhanh2909@gmail.com"

# %%
# !git config --global user.name "tnkhanh"

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
